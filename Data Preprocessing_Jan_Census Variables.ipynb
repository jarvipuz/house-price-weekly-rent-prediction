# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
# G01
age_group = ['Age_0_4_yr_P', 'Age_5_14_yr_P', 'Age_15_19_yr_P', 'Age_20_24_yr_P', 'Age_25_34_yr_P', 'Age_35_44_yr_P',
             'Age_45_54_yr_P', 'Age_55_64_yr_P', 'Age_65_74_yr_P', 'Age_75_84_yr_P', 'Age_85ov_P']
origin = ['Birthplace_Australia_P', 'Birthplace_Elsewhere_P']
educ_attain_G01 = ['High_yr_schl_comp_Yr_12_eq_P', 'High_yr_schl_comp_Yr_11_eq_P', 'High_yr_schl_comp_Yr_10_eq_P',
                   'High_yr_schl_comp_Yr_9_eq_P', 'High_yr_schl_comp_Yr_8_belw_P', 'High_yr_schl_comp_D_n_g_sch_P']

# G02
vars_G02 = ['Median_age_persons', 'Median_tot_prsnl_inc_weekly', 'Median_tot_fam_inc_weekly',
            'Median_tot_hhd_inc_weekly', 'Average_household_size']

# G05
marital_stat = ['P_Tot_Married', 'P_Tot_Separated',  'P_Tot_Divorced',  'P_Tot_Widowed', 'P_Tot_Never_Married']

# G09
country_origin = ['P_Afghanistan_Tot', 'P_Australia_Tot', 'P_Bangladesh_Tot', 'P_Bosnia_Herzegov_Tot',
                  'P_Cambodia_Tot', 'P_Canada_Tot', 'P_Chile_Tot', 'P_China_Tot', 'P_Croatia_Tot', 'P_Egypt_Tot',
                  'P_England_Tot', 'P_Fiji_Tot', 'P_France_Tot', 'P_Germany_Tot', 'P_Greece_Tot', 'P_Hong_Kong_Tot',
                  'P_India_Tot', 'P_Indonesia_Tot', 'P_Iran_Tot', 'P_Iraq_Tot', 'P_Ireland_Tot', 'P_Italy_Tot',
                  'P_Japan_Tot', 'P_Korea_South_Tot', 'P_Lebanon_Tot', 'P_Malaysia_Tot', 'P_Malta_Tot',
                  'P_Mauritius_Tot', 'P_Myanmar_Tot', 'P_Nepal_Tot', 'P_Netherlands_Tot', 'P_New_Zealand_Tot',
                  'P_Nthern_Ireland_Tot', 'P_Pakistan_Tot', 'P_PNG_Tot', 'P_Philippines_Tot', 'P_Poland_Tot',
                  'P_Scotland_Tot', 'P_Singapore_Tot', 'P_South_Africa_Tot', 'P_SE_Europe_nfd_Tot', 'P_Sri_Lanka_Tot',
                  'P_Taiwan_Tot', 'P_Thailand_Tot', 'P_FYROM_Tot', 'P_Turkey_Tot', 'P_USA_Tot', 'P_Vietnam_Tot',
                  'P_Wales_Tot', 'P_Zimbabwe_Tot', 'P_Elsewhere_Tot', 'P_COB_NS_Tot']

# G16
educ_attain_G16 = ['P_Y12e_Tot', 'P_Y11e_Tot', 'P_Y10e_Tot', 'P_Y9e_Tot', 'P_Y8b_Tot', 'P_DNGTS_Tot',
                   'P_Hghst_yr_schl_ns_Tot']

# G17
personal_income = ['LGA_CODE_2016', 'P_Neg_Nil_income_Tot', 'P_1_149_Tot', 'P_150_299_Tot', 'P_300_399_Tot',
                   'P_400_499_Tot', 'P_500_649_Tot', 'P_650_799_Tot', 'P_800_999_Tot', 'P_1000_1249_Tot',
                   'P_1250_1499_Tot', 'P_1500_1749_Tot', 'P_1750_1999_Tot', 'P_2000_2999_Tot', 'P_3000_more_Tot',
                   'P_PI_NS_ns_Tot']

# G28
family_income = ['LGA_CODE_2016', 'Neg_Nil_inc_Tot', 'FI_1_149_Tot', 'FI_150_299_Tot', 'FI_300_399_Tot',
                 'FI_400_499_Tot', 'FI_500_649_Tot', 'FI_650_799_Tot', 'FI_800_999_Tot', 'FI_1000_1249_Tot',
                 'FI_1250_1499_Tot', 'FI_1500_1749_Tot', 'FI_1750_1999_Tot', 'FI_2000_2499_Tot', 'FI_2500_2999_Tot',
                 'FI_3000_3499_Tot', 'FI_3500_3999_Tot', 'FI_4000_more_Tot', 'Partial_income_stated_Tot',
                 'All_incomes_ns_Tot']

# G29
hh_income = ['LGA_CODE_2016', 'Negative_Nil_income_Tot', 'HI_1_149_Tot', 'HI_150_299_Tot', 'HI_300_399_Tot',
             'HI_400_499_Tot', 'HI_500_649_Tot', 'HI_650_799_Tot', 'HI_800_999_Tot', 'HI_1000_1249_Tot',
             'HI_1250_1499_Tot', 'HI_1500_1749_Tot', 'HI_1750_1999_Tot', 'HI_2000_2499_Tot', 'HI_2500_2999_Tot',
             'HI_3000_3499_Tot', 'HI_3500_3999_Tot', 'HI_4000_more_Tot', 'Partial_income_stated_Tot',
             'All_incomes_not_stated_Tot']

# G40
employment = ['LGA_CODE_2016', 'Percent_Unem_loyment_P', 'Percnt_LabForc_prticipation_P',
              'Percnt_Employment_to_populn_P']
non_school_educ_G40 = ['LGA_CODE_2016', 'Non_sch_quals_PostGrad_Dgre_P', 'Non_sch_quals_Gr_Dip_Gr_Crt_P',
                       'Non_sch_quals_Bchelr_Degree_P', 'Non_sch_quls_Advncd_Dip_Dip_P',
                       'Non_sch_quls_Cert3a4_Level_P', 'Non_sch_quls_Cert1a2_Level_P',
                       'Non_sch_quls_Certnfd_Level_P', 'Non_sch_quls_CertTot_Level_P']

# G46
non_school_educ_G46 = ['LGA_CODE_2016', 'P_PGrad_Deg_Total', 'P_GradDip_and_GradCert_Total', 'P_BachDeg_Total',
                       'P_AdvDip_and_Dip_Total', 'P_Cert_III_IV_Total', 'P_Cert_I_II_Total',
                       'P_Cert_Levl_nfd_Total', 'P_Lev_Edu_IDes_Total', 'P_Lev_Edu_NS_Total']

# %%
g17apath = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G17A_NSW_LGA.csv'
g17bpath = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G17B_NSW_LGA.csv'
g17cpath = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G17C_NSW_LGA.csv'
g28path = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G28_NSW_LGA.csv'
g29path = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G29_NSW_LGA.csv'
g40path = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G40_NSW_LGA.csv'
g46apath = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G46A_NSW_LGA.csv'
g46bpath = 'Data/census 2016/2016_GCP_LGA_for_NSW_short-header/2016 Census GCP Local Government Areas for NSW/2016Census_G46B_NSW_LGA.csv'

# %%
df_pincome_1 = pd.read_csv(g17apath)
df_pincome_2 = pd.read_csv(g17bpath)
df_pincome_3 = pd.read_csv(g17cpath)

# %%
df_pincome = df_pincome_1.merge(df_pincome_2, on = 'LGA_CODE_2016', how = 'outer')
df_pincome = df_pincome.merge(df_pincome_3, on = 'LGA_CODE_2016', how = 'outer')
df_pincome = df_pincome[personal_income]
df_pincome.head()
# Out:
#   LGA_CODE_2016  P_Neg_Nil_income_Tot  P_1_149_Tot  P_150_299_Tot  \
# 0      LGA10050                  2655         1701           3030
# 1      LGA10130                  2136         1105           2303
# 2      LGA10250                  2054         1393           2351
# 3      LGA10300                   158           44            101
# 4      LGA10470                  2474         1315           2422
#
#    P_300_399_Tot  P_400_499_Tot  P_500_649_Tot  P_650_799_Tot  P_800_999_Tot  \
# 0           3810           3971           3660           3643           3952
# 1           2186           2217           2127           2154           1809
# 2           3720           3774           3474           3253           2964
# 3            163            157            159            171            187
# 4           2761           2961           2712           2675           2776
#
#    P_1000_1249_Tot  P_1250_1499_Tot  P_1500_1749_Tot  P_1750_1999_Tot  \
# ...

# %%
df_pincome.shape
# Out:
# (132, 16)

# %%
df_pincome.columns
# Out:
# Index(['LGA_CODE_2016', 'P_Neg_Nil_income_Tot', 'P_1_149_Tot', 'P_150_299_Tot',
#        'P_300_399_Tot', 'P_400_499_Tot', 'P_500_649_Tot', 'P_650_799_Tot',
#        'P_800_999_Tot', 'P_1000_1249_Tot', 'P_1250_1499_Tot',
#        'P_1500_1749_Tot', 'P_1750_1999_Tot', 'P_2000_2999_Tot',
#        'P_3000_more_Tot', 'P_PI_NS_ns_Tot'],
#       dtype='object')

# %%
df_pincome['total'] = df_pincome.drop(columns = ['LGA_CODE_2016']).sum(axis = 1)
df_pincome['pct_no_pincome'] = (df_pincome.P_Neg_Nil_income_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_1_499'] = (df_pincome.P_1_149_Tot + df_pincome.P_150_299_Tot + df_pincome.P_300_399_Tot +
                                   df_pincome.P_400_499_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_500_999'] = (df_pincome.P_500_649_Tot + df_pincome.P_650_799_Tot +
                                     df_pincome.P_800_999_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_1_999'] = (df_pincome.P_1_149_Tot + df_pincome.P_150_299_Tot + df_pincome.P_300_399_Tot +
                                   df_pincome.P_400_499_Tot + df_pincome.P_500_649_Tot + df_pincome.P_650_799_Tot +
                                   df_pincome.P_800_999_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_1000_1499'] = (df_pincome.P_1000_1249_Tot +
                                       df_pincome.P_1250_1499_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_1500_1999'] = (df_pincome.P_1500_1749_Tot +
                                       df_pincome.P_1750_1999_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_1000_1999'] = (df_pincome.P_1000_1249_Tot + df_pincome.P_1250_1499_Tot +
                                       df_pincome.P_1500_1749_Tot +
                                       df_pincome.P_1750_1999_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_2000_2999'] = (df_pincome.P_2000_2999_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_3000_more'] = (df_pincome.P_3000_more_Tot) * 100 / df_pincome.total
df_pincome['pct_pincome_ns'] = (df_pincome.P_PI_NS_ns_Tot) * 100 / df_pincome.total

# %%
df_pincome_final = df_pincome[['LGA_CODE_2016', 'pct_no_pincome', 'pct_pincome_1_499', 'pct_pincome_500_999',
                               'pct_pincome_1_999', 'pct_pincome_1000_1499', 'pct_pincome_1500_1999',
                               'pct_pincome_1000_1999', 'pct_pincome_2000_2999', 'pct_pincome_3000_more',
                               'pct_pincome_ns']]
df_pincome_final.head()
# Out:
#   LGA_CODE_2016  pct_no_pincome  pct_pincome_1_499  pct_pincome_500_999  \
# 0      LGA10050        6.403917          30.179213            27.147302
# 1      LGA10130        8.853519          32.375860            25.242477
# 2      LGA10250        5.892140          32.237522            27.799771
# 3      LGA10300        8.743774          25.733260            28.610957
# 4      LGA10470        7.452481          28.493539            24.589571
#
#    pct_pincome_1_999  pct_pincome_1000_1499  pct_pincome_1500_1999  \
# 0          57.326515              14.189923               7.132348
# 1          57.618337              11.634751               6.262953
# 2          60.037292              12.059667               6.534710
# 3          54.344217              12.838960               3.818484
# 4          53.083110              13.519294               8.178450
#
#    pct_pincome_1000_1999  pct_pincome_2000_2999  pct_pincome_3000_more  \
# ...

# %%
df_fincome = pd.read_csv(g28path)
df_fincome = df_fincome[family_income]
df_fincome.head()
# Out:
#   LGA_CODE_2016  Neg_Nil_inc_Tot  FI_1_149_Tot  FI_150_299_Tot  \
# 0      LGA10050               89            62             113
# 1      LGA10130               66            30              73
# 2      LGA10250               57            43              89
# 3      LGA10300               11             0              11
# 4      LGA10470               69            51              94
#
#    FI_300_399_Tot  FI_400_499_Tot  FI_500_649_Tot  FI_650_799_Tot  \
# 0             125             429             460            1089
# 1              68             233             273             605
# 2              84             355             374            1197
# 3               0              14              23              42
# 4              99             314             359             786
#
#    FI_800_999_Tot  FI_1000_1249_Tot  FI_1250_1499_Tot  FI_1500_1749_Tot  \
# 0             907              1158              1186               883
# ...

# %%
df_fincome.shape
# Out:
# (132, 20)

# %%
df_fincome.columns
# Out:
# Index(['LGA_CODE_2016', 'Neg_Nil_inc_Tot', 'FI_1_149_Tot', 'FI_150_299_Tot',
#        'FI_300_399_Tot', 'FI_400_499_Tot', 'FI_500_649_Tot', 'FI_650_799_Tot',
#        'FI_800_999_Tot', 'FI_1000_1249_Tot', 'FI_1250_1499_Tot',
#        'FI_1500_1749_Tot', 'FI_1750_1999_Tot', 'FI_2000_2499_Tot',
#        'FI_2500_2999_Tot', 'FI_3000_3499_Tot', 'FI_3500_3999_Tot',
#        'FI_4000_more_Tot', 'Partial_income_stated_Tot', 'All_incomes_ns_Tot'],
#       dtype='object')

# %%
df_fincome['total'] = df_fincome.drop(columns = ['LGA_CODE_2016']).sum(axis = 1)
df_fincome['pct_no_fincome'] = (df_fincome.Neg_Nil_inc_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_1_499'] = (df_fincome.FI_1_149_Tot + df_fincome.FI_150_299_Tot + df_fincome.FI_300_399_Tot +
                                   df_fincome.FI_400_499_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_500_999'] = (df_fincome.FI_500_649_Tot + df_fincome.FI_650_799_Tot +
                                     df_fincome.FI_800_999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_1_999'] = (df_fincome.FI_1_149_Tot + df_fincome.FI_150_299_Tot + df_fincome.FI_300_399_Tot +
                                   df_fincome.FI_400_499_Tot + df_fincome.FI_500_649_Tot + df_fincome.FI_650_799_Tot +
                                   df_fincome.FI_800_999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_1000_1499'] = (df_fincome.FI_1000_1249_Tot +
                                       df_fincome.FI_1250_1499_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_1500_1999'] = (df_fincome.FI_1500_1749_Tot +
                                       df_fincome.FI_1750_1999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_1000_1999'] = (df_fincome.FI_1000_1249_Tot + df_fincome.FI_1250_1499_Tot +
                                       df_fincome.FI_1500_1749_Tot +
                                       df_fincome.FI_1750_1999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_2000_2999'] = (df_fincome.FI_2000_2499_Tot +
                                       df_fincome.FI_2500_2999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_3000_3999'] = (df_fincome.FI_3000_3499_Tot +
                                       df_fincome.FI_3500_3999_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_4000_more'] = (df_fincome.FI_4000_more_Tot) * 100 / df_fincome.total
df_fincome['pct_part_fincome'] = (df_fincome.Partial_income_stated_Tot) * 100 / df_fincome.total
df_fincome['pct_fincome_ns'] = (df_fincome.All_incomes_ns_Tot) * 100 / df_fincome.total

# %%
df_fincome_final = df_fincome[['LGA_CODE_2016', 'pct_no_fincome', 'pct_fincome_1_499', 'pct_fincome_500_999',
                               'pct_fincome_1_999', 'pct_fincome_1000_1499', 'pct_fincome_1500_1999',
                               'pct_fincome_1000_1999', 'pct_fincome_2000_2999', 'pct_fincome_3000_3999',
                               'pct_fincome_4000_more', 'pct_fincome_ns']]
df_fincome_final.head()
# Out:
#   LGA_CODE_2016  pct_no_fincome  pct_fincome_1_499  pct_fincome_500_999  \
# 0      LGA10050        0.693633           5.681552            19.141143
# 1      LGA10130        0.954861           5.844907            20.355903
# 2      LGA10250        0.505319           5.062057            21.728723
# 3      LGA10300        1.909722           4.340278            19.444444
# 4      LGA10470        0.679937           5.498620            17.836027
#
#    pct_fincome_1_999  pct_fincome_1000_1499  pct_fincome_1500_1999  \
# 0          24.822695              18.268257              13.615463
# 1          26.200810              18.243634              13.469329
# 2          26.790780              20.239362              13.156028
# 3          23.784722              19.270833              15.972222
# 4          23.334647              17.027986              12.859677
#
#    pct_fincome_1000_1999  pct_fincome_2000_2999  pct_fincome_3000_3999  \
# ...

# %%
df_hincome = pd.read_csv(g29path)
df_hincome = df_hincome[hh_income]
df_hincome.head()
# Out:
#   LGA_CODE_2016  Negative_Nil_income_Tot  HI_1_149_Tot  HI_150_299_Tot  \
# 0      LGA10050                      220           145             497
# 1      LGA10130                      134            78             284
# 2      LGA10250                      141            88             312
# 3      LGA10300                       14             5              17
# 4      LGA10470                      154            94             340
#
#    HI_300_399_Tot  HI_400_499_Tot  HI_500_649_Tot  HI_650_799_Tot  \
# 0             757            1598            1105            1680
# 1             367             805             596             923
# 2             547            1418             946            1602
# 3              34              55              33              65
# 4             429            1115             757            1094
#
#    HI_800_999_Tot  HI_1000_1249_Tot  HI_1250_1499_Tot  HI_1500_1749_Tot  \
# ...

# %%
df_hincome.shape
# Out:
# (132, 20)

# %%
df_hincome.columns
# Out:
# Index(['LGA_CODE_2016', 'Negative_Nil_income_Tot', 'HI_1_149_Tot',
#        'HI_150_299_Tot', 'HI_300_399_Tot', 'HI_400_499_Tot', 'HI_500_649_Tot',
#        'HI_650_799_Tot', 'HI_800_999_Tot', 'HI_1000_1249_Tot',
#        'HI_1250_1499_Tot', 'HI_1500_1749_Tot', 'HI_1750_1999_Tot',
#        'HI_2000_2499_Tot', 'HI_2500_2999_Tot', 'HI_3000_3499_Tot',
#        'HI_3500_3999_Tot', 'HI_4000_more_Tot', 'Partial_income_stated_Tot',
#        'All_incomes_not_stated_Tot'],
#       dtype='object')

# %%
df_hincome['total'] = df_fincome.drop(columns = ['LGA_CODE_2016']).sum(axis = 1)
df_hincome['pct_no_hincome'] = (df_hincome.Negative_Nil_income_Tot) / df_hincome.total
df_hincome['pct_hincome_1_499'] = (df_hincome.HI_1_149_Tot + df_hincome.HI_150_299_Tot + df_hincome.HI_300_399_Tot +
                                   df_hincome.HI_400_499_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_500_999'] = (df_hincome.HI_500_649_Tot + df_hincome.HI_650_799_Tot +
                                     df_hincome.HI_800_999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_1_999'] = (df_hincome.HI_1_149_Tot + df_hincome.HI_150_299_Tot + df_hincome.HI_300_399_Tot +
                                   df_hincome.HI_400_499_Tot + df_hincome.HI_500_649_Tot + df_hincome.HI_650_799_Tot +
                                   df_hincome.HI_800_999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_1000_1499'] = (df_hincome.HI_1000_1249_Tot +
                                       df_hincome.HI_1250_1499_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_1500_1999'] = (df_hincome.HI_1500_1749_Tot +
                                       df_hincome.HI_1750_1999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_1000_1999'] = (df_hincome.HI_1000_1249_Tot + df_hincome.HI_1250_1499_Tot +
                                       df_hincome.HI_1500_1749_Tot +
                                       df_hincome.HI_1750_1999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_2000_2999'] = (df_hincome.HI_2000_2499_Tot +
                                       df_hincome.HI_2500_2999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_3000_3999'] = (df_hincome.HI_3000_3499_Tot +
                                       df_hincome.HI_3500_3999_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_4000_more'] = (df_hincome.HI_4000_more_Tot) * 100 / df_hincome.total
df_hincome['pct_part_hincome'] = (df_hincome.Partial_income_stated_Tot) * 100 / df_hincome.total
df_hincome['pct_hincome_ns'] = (df_hincome.All_incomes_not_stated_Tot) * 100 / df_hincome.total

# %%
df_hincome_final = df_hincome[['LGA_CODE_2016', 'pct_no_hincome', 'pct_hincome_1_499', 'pct_hincome_500_999',
                               'pct_hincome_1_999', 'pct_hincome_1000_1499', 'pct_hincome_1500_1999',
                               'pct_hincome_1000_1999', 'pct_hincome_2000_2999', 'pct_hincome_3000_3999',
                               'pct_hincome_4000_more', 'pct_part_hincome', 'pct_hincome_ns']]
df_hincome_final.head()
# Out:
#   LGA_CODE_2016  pct_no_hincome  pct_hincome_1_499  pct_hincome_500_999  \
# 0      LGA10050        0.008521          11.607863            16.840503
# 1      LGA10130        0.009584          10.971316            16.571408
# 2      LGA10250        0.006206          10.409246            16.769229
# 3      LGA10300        0.010679           8.466640            11.899061
# 4      LGA10470        0.007531           9.672739            14.039654
#
#    pct_hincome_1_999  pct_hincome_1000_1499  pct_hincome_1500_1999  \
# 0          28.448366              12.765938               8.513207
# 1          27.542725              11.936849               8.618277
# 2          27.178474              12.539510               7.865252
# 3          20.365701              10.678645               8.085260
# 4          23.712393              11.506550               8.269263
#
#    pct_hincome_1000_1999  pct_hincome_2000_2999  pct_hincome_3000_3999  \
# ...

# %%
df_census40 = pd.read_csv(g40path)
df_employment = df_census40[employment]
df_heduc40 = df_census40[non_school_educ_G40]
print(df_employment.shape)
print(df_heduc40.shape)
# Out:
# (132, 4)
# (132, 9)

# %%
df_employment.head()
# Out:
#   LGA_CODE_2016  Percent_Unem_loyment_P  Percnt_LabForc_prticipation_P  \
# 0      LGA10050                     6.8                           59.3
# 1      LGA10130                     7.7                           55.4
# 2      LGA10250                     5.9                           53.2
# 3      LGA10300                     5.3                           57.8
# 4      LGA10470                     6.0                           58.3
#
#    Percnt_Employment_to_populn_P
# 0                           55.2
# 1                           51.1
# 2                           50.1
# 3                           54.4
# 4                           54.8

# %%
df_heduc40.head()
# Out:
#   LGA_CODE_2016  Non_sch_quals_PostGrad_Dgre_P  Non_sch_quals_Gr_Dip_Gr_Crt_P  \
# 0      LGA10050                           1047                            843
# 1      LGA10130                           1741                            571
# 2      LGA10250                           1071                            741
# 3      LGA10300                             21                             13
# 4      LGA10470                            951                            645
#
#    Non_sch_quals_Bchelr_Degree_P  Non_sch_quls_Advncd_Dip_Dip_P  \
# 0                           4703                           3530
# 1                           3285                           1729
# 2                           4734                           3324
# 3                             94                             80
# 4                           3759                           2672
#
#    Non_sch_quls_Cert3a4_Level_P  Non_sch_quls_Cert1a2_Level_P  \
# ...

# %%
df_heduc46_1 = pd.read_csv(g46apath)
df_heduc46_2 = pd.read_csv(g46bpath)
df_heduc46 = df_heduc46_1.merge(df_heduc46_2, on = 'LGA_CODE_2016', how = 'outer')
df_heduc46 = df_heduc46[non_school_educ_G46]
df_heduc46.head()
# Out:
#   LGA_CODE_2016  P_PGrad_Deg_Total  P_GradDip_and_GradCert_Total  \
# 0      LGA10050               1047                           843
# 1      LGA10130               1741                           571
# 2      LGA10250               1071                           741
# 3      LGA10300                 21                            13
# 4      LGA10470                951                           645
#
#    P_BachDeg_Total  P_AdvDip_and_Dip_Total  P_Cert_III_IV_Total  \
# 0             4703                    3530                 8334
# 1             3285                    1729                 3482
# 2             4734                    3324                 6380
# 3               94                      80                  250
# 4             3759                    2672                 6508
#
#    P_Cert_I_II_Total  P_Cert_Levl_nfd_Total  P_Lev_Edu_IDes_Total  \
# 0                644                    888                   309
# ...

# %%
df_heduc46.shape
# Out:
# (132, 10)

# %%
df_heduc46['total'] = df_heduc46.drop(columns = ['LGA_CODE_2016']).sum(axis = 1)
df_heduc46['pct_pgrad'] = (df_heduc46.P_PGrad_Deg_Total) * 100 / df_heduc46.total
df_heduc46['pct_grad_cert_dip'] = (df_heduc46.P_GradDip_and_GradCert_Total) * 100 / df_heduc46.total
df_heduc46['pct_bach_deg'] = (df_heduc46.P_BachDeg_Total) * 100 / df_heduc46.total
df_heduc46['pct_adv_dip'] = (df_heduc46.P_AdvDip_and_Dip_Total) * 100 / df_heduc46.total
df_heduc46['pct_cert_iii_iv'] = (df_heduc46.P_Cert_III_IV_Total) * 100 / df_heduc46.total
df_heduc46['pct_cert_i_ii'] = (df_heduc46.P_Cert_I_II_Total +
                               df_heduc46.P_Cert_Levl_nfd_Total) * 100 / df_heduc46.total
df_heduc46['pct_others'] = (df_heduc46.P_Lev_Edu_IDes_Total + df_heduc46.P_Lev_Edu_NS_Total) * 100 / df_heduc46.total

# %%
df_heduc_final = df_heduc46[['LGA_CODE_2016', 'pct_pgrad', 'pct_grad_cert_dip', 'pct_bach_deg', 'pct_adv_dip',
                             'pct_cert_iii_iv', 'pct_cert_i_ii', 'pct_others']]
df_heduc_final.head()
# Out:
#   LGA_CODE_2016  pct_pgrad  pct_grad_cert_dip  pct_bach_deg  pct_adv_dip  \
# 0      LGA10050   4.264418           3.433529     19.155262    14.377647
# 1      LGA10130  12.040111           3.948824     22.717842    11.957123
# 2      LGA10250   4.923233           3.406270     21.761515    15.279949
# 3      LGA10300   2.618454           1.620948     11.720698     9.975062
# 4      LGA10470   4.664509           3.163626     18.437316    13.105748
#
#    pct_cert_iii_iv  pct_cert_i_ii  pct_others
# 0        33.944282       6.239818   18.585044
# 1        24.080221       5.767635   19.488243
# 2        29.327940       6.288499   19.012595
# 3        31.172070       5.610973   37.281796
# 4        31.920738       6.592113   22.115951

# %%
lga_census = [df_pincome_final, df_fincome_final, df_hincome_final, df_employment, df_heduc_final]
df_census_2 = reduce(lambda left, right: pd.merge(left, right, on = ['LGA_CODE_2016'], how = 'outer'), lga_census)
df_census_2.head()
df_census_2 = df_census_2.rename(columns = {'LGA_CODE_2016':'LGA_CODE'})

# %%
df_census_2.to_csv('Data/census 2016/census2016_file02.csv', index = False)
